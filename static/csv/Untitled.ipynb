# %%
import pandas as pd
df = pd.read_csv('./all_fixation_data_cleaned_up.csv',encoding='latin-1',sep='\t')
df_grouped= df.sort_values(by=['StimuliName','user','Timestamp']).groupby(['StimuliName','user'])
counter = 2
for name,group in df_grouped:
    counter -= 1
    resetted = group.reset_index()
    display(resetted.head(1)['Timestamp'])
    group.loc[:,'Timestamp'] = group['Timestamp'] - resetted.head(1)['Timestamp'][0]
    display(group)
    if(counter == 0):
        break
# Out:
# 0    2586
# Name: Timestamp, dtype: int64
# /home/marti_2203/.local/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#     Timestamp          StimuliName  FixationIndex  FixationDuration  \
# 0           0  01_Antwerpen_S1.jpg              9               250
# 1         250  01_Antwerpen_S1.jpg             10               150
# 2         400  01_Antwerpen_S1.jpg             11               283
# 3         683  01_Antwerpen_S1.jpg             12               433
# 4        1116  01_Antwerpen_S1.jpg             13               183
# 5        1299  01_Antwerpen_S1.jpg             14               333
# ...
